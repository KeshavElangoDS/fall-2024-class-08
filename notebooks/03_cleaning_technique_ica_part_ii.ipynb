# %% [markdown]
# # Example 03: Cleaning a Larger Dataset with ICA
#
# Here we use ICA to clean a larger data and find some interesting patterns!

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

import pandas as pd
import os
import json
import matplotlib.pyplot as plt
import numpy as np

# from notebooks.feature_extraction import get_autoregression_features
from feature_extraction import get_autoregression_features

plt.rcParams["font.size"] = 16
plt.rcParams["font.family"] = "serif"
plt.rcParams["mathtext.fontset"] = "dejavuserif"

np.random.seed(42)

def read_kaggle_json(filepath):
    filepath = os.path.expanduser(filepath)
    username = None
    token = None
    with open(filepath, "r") as file:
        config = json.load(file)
        username = config.get("username")
        token = config.get("key")
    return username, token


# kaggle_json_filepath = "/workspaces/fall-2024-class-08/kaggle/kaggle.json"
# kaggle_username, kaggle_api_token = read_kaggle_json(kaggle_json_filepath)

# if kaggle_username and kaggle_api_token:
#     os.environ["KAGGLE_USERNAME"] = kaggle_username
#     os.environ["KAGGLE_KEY"] = kaggle_api_token

# import kaggle

# dataset_name = "andrewmvd/sp-500-stocks"
# download_location = "/workspaces/fall-2024-class-08/downloads"

# kaggle.api.authenticate()
# kaggle.api.dataset_download_files(
#     dataset_name, path=download_location, unzip=True
# )

from os import path
basepath = path.dirname(os.getcwd())

kaggle_json_filepath = path.abspath(path.join(basepath, "./kaggle/kaggle.json"))
# kaggle_json_filepath = "/workspaces/fall-2024-class-08/kaggle/kaggle.json"
kaggle_username, kaggle_api_token = read_kaggle_json(kaggle_json_filepath)

if kaggle_username and kaggle_api_token:
    os.environ["KAGGLE_USERNAME"] = kaggle_username
    os.environ["KAGGLE_KEY"] = kaggle_api_token

import kaggle

dataset_name = "andrewmvd/sp-500-stocks"
download_filepath = path.abspath(path.join(basepath, "./downloads"))
# download_location = "/workspaces/fall-2024-class-08/downloads"

kaggle.api.authenticate()
kaggle.api.dataset_download_files(
    dataset_name, path=download_filepath, unzip=True
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Dataset URL: https://www.kaggle.com/datasets/andrewmvd/sp-500-stocks

# %%
# stocks_file_path = "/workspaces/fall-2024-class-08/downloads/sp500_stocks.csv"
# index_file_path = "/workspaces/fall-2024-class-08/downloads/sp500_index.csv"
# companies_file_path = (
#     "/workspaces/fall-2024-class-08/downloads/sp500_companies.csv"
# )

# stocks_df = pd.read_csv(stocks_file_path)
# index_df = pd.read_csv(index_file_path)
# companies_df = pd.read_csv(companies_file_path)
# dates = stocks_df["Date"].unique()
# symbols = companies_df["Symbol"].unique()
# print(symbols)

stocks_file_path = "./sp500_stocks.csv"
index_file_path = "./sp500_index.csv"
companies_file_path = "./sp500_companies.csv"

# stocks_file_path = "/workspaces/fall-2024-class-08/downloads/sp500_stocks.csv"
# index_file_path = "/workspaces/fall-2024-class-08/downloads/sp500_index.csv"
# companies_file_path = "/workspaces/fall-2024-class-08/downloads/sp500_companies.csv"

stocks_df = pd.read_csv(os.path.join(download_filepath,stocks_file_path))
index_df = pd.read_csv(os.path.join(download_filepath,index_file_path))
companies_df = pd.read_csv(os.path.join(download_filepath,companies_file_path))

dates = stocks_df["Date"].unique()
symbols = companies_df["Symbol"].unique()
print(symbols)
# Out:
# ['AAPL' 'NVDA' 'MSFT' 'GOOG' 'GOOGL' 'AMZN' 'META' 'BRK-B' 'TSLA' 'AVGO'
#  'LLY' 'WMT' 'JPM' 'V' 'UNH' 'XOM' 'ORCL' 'MA' 'PG' 'HD' 'COST' 'JNJ'
#  'ABBV' 'BAC' 'NFLX' 'KO' 'CRM' 'CVX' 'MRK' 'TMUS' 'AMD' 'PEP' 'LIN' 'WFC'
#  'CSCO' 'ACN' 'ADBE' 'TMO' 'MCD' 'BX' 'PM' 'ABT' 'NOW' 'AXP' 'TXN' 'MS'
#  'GE' 'IBM' 'QCOM' 'CAT' 'ISRG' 'DHR' 'INTU' 'VZ' 'DIS' 'AMGN' 'UBER' 'GS'
#  'CMCSA' 'NEE' 'RTX' 'PFE' 'T' 'AMAT' 'SPGI' 'BKNG' 'LOW' 'BLK' 'PGR'
#  'UNP' 'SYK' 'ETN' 'HON' 'SCHW' 'KKR' 'TJX' 'LMT' 'ANET' 'BSX' 'VRTX' 'C'
#  'COP' 'ADP' 'PANW' 'ADI' 'MDT' 'MU' 'UPS' 'CB' 'NKE' 'FI' 'DE' 'SBUX'
#  'GILD' 'MMC' 'PLD' 'BMY' 'REGN' 'PLTR' 'AMT' 'LRCX' 'SO' 'ICE' 'BA'
#  'INTC' 'ELV' 'MDLZ' 'HCA' 'KLAC' 'SHW' 'DUK' 'WM' 'CI' 'ABNB' 'EQIX' 'MO'
#  'WELL' 'DELL' 'TT' 'CTAS' 'MCO' 'APH' 'GD' 'ZTS' 'SNPS' 'GEV' 'CEG' 'CME'
#  'PH' 'AON' 'CDNS' 'PYPL' 'ITW' 'CL' 'CMG' 'CRWD' 'USB' 'MSI' 'PNC' 'TDG'
#  'MAR' 'NOC' 'ECL' 'CVS' 'APD' 'MMM' 'EOG' 'TGT' 'BDX' 'ORLY' 'FDX' 'FCX'
#  'CARR' 'NXPI' 'CSX' 'MCK' 'SPG' 'RSG' 'WMB' 'COF' 'AJG' 'ADSK' 'EMR'
#  'AFL' 'DLR' 'FTNT' 'ROP' 'PSA' 'MET' 'HLT' 'TFC' 'NSC' 'GM' 'TRV' 'SLB'
#  'RCL' 'OKE' 'BK' 'KMI' 'DHI' 'PCAR' 'GWW' 'NEM' 'URI' 'SRE' 'PCG' 'O'
#  'AEP' 'AZO' 'FANG' 'MNST' 'PSX' 'JCI' 'PAYX' 'CPRT' 'AMP' 'ALL' 'FIS'
#  'AIG' 'FICO' 'D' 'MPC' 'CHTR' 'OXY' 'CCI' 'LHX' 'TEL' 'ROST' 'LEN' 'PWR'
#  'MPWR' 'CMI' 'COR' 'MSCI' 'PRU' 'FAST' 'KMB' 'KDP' 'PEG' 'KVUE' 'ODFL'
#  'VST' 'NDAQ' 'STZ' 'CTVA' 'F' 'HES' 'EW' 'HWM' 'VLO' 'GLW' 'KHC' 'MCHP'
#  'CBRE' 'KR' 'IT' 'GEHC' 'EXC' 'ACGL' 'EA' 'GRMN' 'IQV' 'OTIS' 'VRSK' 'IR'
#  'AME' 'DFS' 'LVS' 'GIS' 'A' 'DAL' 'YUM' 'IRM' 'LULU' 'IDXX' 'BKR' 'MLM'
#  'CTSH' 'TRGP' 'VMC' 'SYY' 'EXR' 'HSY' 'RMD' 'ED' 'XEL' 'HPQ' 'DD' 'DOW'
#  'VICI' 'NUE' 'AXON' 'EFX' 'MTB' 'HIG' 'WAB' 'AVB' 'EIX' 'HUM' 'XYL' 'ON'
#  'EL' 'CNC' 'EBAY' 'ROK' 'WEC' 'RJF' 'BRO' 'CSGP' 'WTW' 'FITB' 'CCL' 'CDW'
#  'PPG' 'TSCO' 'EQR' 'SMCI' 'ETR' 'ANSS' 'TTWO' 'LYB' 'DXCM' 'K' 'NVR'
#  'MTD' 'VTR' 'STT' 'LYV' 'KEYS' 'PHM' 'ADM' 'DOV' 'AWK' 'UAL' 'HPE' 'BIIB'
#  'TYL' 'GPN' 'CAH' 'SW' 'IFF' 'DECK' 'DTE' 'VLTO' 'HST' 'FTV' 'DVN' 'LDOS'
#  'TROW' 'SBAC' 'BR' 'CHD' 'HAL' 'NTAP' 'FE' 'PPL' 'ERIE' 'HUBB' 'WDC' 'ES'
#  'AEE' 'WY' 'CPAY' 'ROL' 'EQT' 'HBAN' 'GDDY' 'PTC' 'WST' 'CINF' 'ZBH'
#  'STE' 'WRB' 'CBOE' 'SYF' 'RF' 'ATO' 'TDY' 'BF-B' 'FSLR' 'STX' 'MRNA'
#  'EXPE' 'COO' 'CMS' 'MKC' 'TSN' 'PKG' 'STLD' 'INVH' 'BLDR' 'NTRS' 'OMC'
#  'ARE' 'ZBRA' 'ESS' 'BALL' 'BBY' 'WAT' 'PFG' 'CLX' 'LH' 'CNP' 'WBD' 'CFG'
#  'LUV' 'HOLX' 'DRI' 'FOX' 'MOH' 'FOXA' 'TER' 'JBHT' 'BAX' 'NRG' 'MAA'
#  'ULTA' 'CTRA' 'L' 'J' 'SNA' 'FDS' 'DGX' 'DG' 'KEY' 'MAS' 'VRSN' 'IP'
#  'EXPD' 'HRL' 'AVY' 'GEN' 'IEX' 'EG' 'PNR' 'UDR' 'PODD' 'APTV' 'KIM' 'GPC'
#  'AMCR' 'ALGN' 'DOC' 'NWS' 'NWSA' 'NI' 'SWKS' 'AKAM' 'LNT' 'BXP' 'TXT'
#  'TRMB' 'RVTY' 'CF' 'MRO' 'SWK' 'NDSN' 'DPZ' 'INCY' 'VTRS' 'JBL' 'CAG'
#  'POOL' 'CPB' 'FFIV' 'CE' 'EVRG' 'UHS' 'DLTR' 'JKHY' 'REG' 'CHRW' 'JNPR'
#  'SOLV' 'RL' 'MGM' 'CPT' 'EMN' 'BG' 'SJM' 'ALLE' 'TECH' 'DVA' 'AES' 'TAP'
#  'KMX' 'TPR' 'ALB' 'IPG' 'ENPH' 'MKTX' 'TFX' 'DAY' 'EPAM' 'LW' 'AOS'
#  'WYNN' 'BEN' 'CTLT' 'NCLH' 'AIZ' 'GNRC' 'PNW' 'PAYC' 'HII' 'CZR' 'LKQ'
#  'FRT' 'GL' 'QRVO' 'MTCH' 'CRL' 'HAS' 'HSIC' 'APA' 'MOS' 'MHK' 'FMC' 'WBA'
#  'IVZ' 'BWA' 'PARA' 'AMTM']

# %%
# Specify the target symbol to predict, number of days of history to use in the
# autoregressive model, and number of days forward to predict.
# Increasing the history (to 20, 50, etc.) will increase the smoothness.
n_days_history = 1
n_days_forward = 1

# Get the dataset
x_features = get_autoregression_features(
    dates, stocks_df, n_days_history, n_days_forward, predictor_symbols=symbols
)

plt.figure(figsize=(6, 4))
plt.plot(x_features, color="k", linewidth=0.1, alpha=0.5)
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from sklearn.decomposition import FastICA
from sklearn.preprocessing import StandardScaler

# from notebooks.ica_tools import (
from ica_tools import (
    perform_n_components_search,
    compute_gaussianity_measure,
    rebuild_features_without_noise,
)

# %%
# Remove NaNs
x_features[np.isnan(x_features)] = 0

# Standardize
scaler = StandardScaler()
x_features_scaled = scaler.fit_transform(x_features)

best_n_components = perform_n_components_search(x_features_scaled)
# Out:
# Checked n = 2, peak to avg. Gaussianity ratio = 1.1357160622082036
# Checked n = 3, peak to avg. Gaussianity ratio = 1.3843656702288238
# Checked n = 4, peak to avg. Gaussianity ratio = 1.7405411557835069
# Checked n = 5, peak to avg. Gaussianity ratio = 2.380636326564218
# Checked n = 6, peak to avg. Gaussianity ratio = 2.0543853525626434
# Checked n = 7, peak to avg. Gaussianity ratio = 2.50491873450893
# /Users/keshavelango/Documents/GitHub/ruc-practical-ai/fall-2024-class-08/.venv/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# Checked n = 8, peak to avg. Gaussianity ratio = 2.3377550665110243
# /Users/keshavelango/Documents/GitHub/ruc-practical-ai/fall-2024-class-08/.venv/lib/python3.12/site-packages/sklearn/decomposition/_fastica.py:128: ConvergenceWarning: FastICA did not converge. Consider increasing tolerance or the maximum number of iterations.
#   warnings.warn(
# Checked n = 9, peak to avg. Gaussianity ratio = 2.6210992956494605
# Checked n = 10, peak to avg. Gaussianity ratio = 2.8861884030930294
# Checked n = 11, peak to avg. Gaussianity ratio = 2.8387438512363756
# Checked n = 12, peak to avg. Gaussianity ratio = 3.288822638912512
# Checked n = 13, peak to avg. Gaussianity ratio = 3.8427328478033314
# Checked n = 14, peak to avg. Gaussianity ratio = 4.29448254169231
# Checked n = 15, peak to avg. Gaussianity ratio = 3.095310443688213
# Checked n = 16, peak to avg. Gaussianity ratio = 2.6400886126486327
# Checked n = 17, peak to avg. Gaussianity ratio = 2.7565647505577444
# Checked n = 18, peak to avg. Gaussianity ratio = 2.7713490934574523
# Checked n = 19, peak to avg. Gaussianity ratio = 2.85833199894724
# Checked n = 20, peak to avg. Gaussianity ratio = 2.036674752089072
# Checked n = 21, peak to avg. Gaussianity ratio = 6.907883936079021
# Checked n = 22, peak to avg. Gaussianity ratio = 3.4697425822756824
# Checked n = 23, peak to avg. Gaussianity ratio = 2.584598229282056
# Checked n = 24, peak to avg. Gaussianity ratio = 2.0406016493027574
# Checked n = 25, peak to avg. Gaussianity ratio = 2.1956074173930564
# Checked n = 26, peak to avg. Gaussianity ratio = 2.126935789222994
# Checked n = 27, peak to avg. Gaussianity ratio = 2.2478880461454094
# Checked n = 28, peak to avg. Gaussianity ratio = 2.4855956975045976
# Checked n = 29, peak to avg. Gaussianity ratio = 3.4211909061507297

# %%
ica = FastICA(
    n_components=21,
    whiten="arbitrary-variance",
    tol=1e-7,
    max_iter=500,
    random_state=42,
)

x_features_transformed = ica.fit_transform(x_features_scaled)

for idx in range(x_features_transformed.shape[1]):
    signal_component = x_features_transformed[:, idx]
    gaussianity_measure = compute_gaussianity_measure(signal_component)
    plt.figure(figsize=(6, 2))
    plt.plot(signal_component, color="k", linewidth=1)
    plt.title("Gaussianity Measure = {}".format(gaussianity_measure))
    plt.tight_layout()
# Out:
# /var/folders/m6/39z99jrd3rq2vk51v5xvjkv80000gn/T/ipykernel_36462/2135601816.py:14: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(6, 2))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_smooth_original_scale, delta = rebuild_features_without_noise(
    ica, scaler, x_features, x_features_transformed
)

plt.figure(figsize=(12, 6))
plt.plot(x_smooth_original_scale, color="b", linewidth=0.15, alpha=0.75)
plt.plot(x_features, color="r", linewidth=0.15, alpha=0.75)
plt.tight_layout()

plt.figure(figsize=(12, 4))
_ = plt.plot(delta, color="k", linewidth=0.1, alpha=0.75)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
